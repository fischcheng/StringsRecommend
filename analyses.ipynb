# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('sf_ratings.csv')

# %%
df.shape
# Out:
# (2422, 11)

# %%
df[df['rts']>2].sort_values('PPR',ascending=False)
# Out:
#        Comfort   Control  Durability      Feel  Overall   PPR     Power  \
# 539   0.214286  0.547619    0.285714  0.380952     16.0  8.46  0.285714
# 659   0.452381  0.619048    0.666667  0.214286     15.0  7.00 -0.166667
# 719   0.476190  0.738095    0.333333  0.476190     18.0  6.25  0.142857
# 893   1.000000  0.666667    0.000000  0.595238     21.0  6.00  0.428571
# 266   0.523810  0.523810    0.380952  0.428571     16.0  5.75  0.238095
# 465   0.452381  0.380952    0.571429  0.380952     19.0  5.60  0.333333
# 831   0.666667  0.595238    0.095238  0.761905     16.0  5.50  0.166667
# 716   0.666667  0.595238    0.214286  0.595238     15.0  5.25 -0.071429
# 1141  0.547619  0.214286    0.500000  0.547619     18.0  5.20  0.214286
# 405   0.595238  0.571429   -0.261905  0.523810     17.0  4.80  0.452381
# 250   0.285714  0.261905    0.476190  0.023810      9.0  4.80  0.214286
# 888  -0.095238  0.595238    0.785714  0.166667     10.0  4.67 -0.166667
# ...

# %% [markdown]
# ### Ideas
# * A 3d plot: three axes: control<>power, spin<>comfort, feel<>durability
# * A unsupervised clustering
# * Predict Overall using all ratings (7 categories)
# * A bar plot show all strings Overall ratings

# %% [markdown]
# ### Another data source: http://twu.tennis-warehouse.com/learning_center/reporter2.php
